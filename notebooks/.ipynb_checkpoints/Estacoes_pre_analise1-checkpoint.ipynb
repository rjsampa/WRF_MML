# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Estacoes
dataframe = pd.read_pickle('../dados_meteorologicos/Alerta_rio_csv/temperatura.pk')

# %%
dataframe.plot(subplots = True, figsize = (14,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1f0abe0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1e8e080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1e384e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1e5f940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1e05da0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1db7240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdf1ddd6a0>],
#       dtype=object)

# %%
# separando 2017
temp2017=dataframe.loc['2017-01-01':'2017-12-31']

# %%
# convertendo para dados horários
temp2017 = temp2017.resample('H').mean()

# %%
temp2017.plot(subplots=True, figsize = (15,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7efdeae83e48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdeaeb00b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdeae59518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdeadff978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdeae29dd8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdeadda278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efdead7f6d8>],
#       dtype=object)

# %%
temp2017.loc['2017-12-22'].plot()

# %%
estacoes = pd.read_csv('../../dados_informacoes/vetores/estacoes_shape/estacoes_info.csv')

# %% [markdown]
# # Estacoes INMET
